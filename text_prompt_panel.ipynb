# %%
# %%html
# <style>
# .pre-wrap { white-space:pre-wrap }
# </style>
# Out:
# <style>
# .pre-wrap { white-space:pre-wrap }
#
# </style>

# %%
# Utils widgets
from ipywidgets import Button, Layout, jslink, IntText, IntSlider
from ipywidgets import AppLayout, Button, Layout
import ipywidgets as widgets
from ipywidgets import interactive
import asyncio
import nest_asyncio
nest_asyncio.apply()
from grpclib.client import Channel
from proto.seq2seq_grpc import Seq2SeqStub

from proto.seq2seq_pb2 import PromptRequest, PromptReply

def create_expanded_html(description, button_style):
    return widgets.HTML(description=description, button_style=button_style, layout=Layout(height='auto', width='auto'))

async def stream_prompt() -> None:
    channel = Channel(port = 50050)
    stub = Seq2SeqStub(channel)
    res = prompt.value
    # This block performs the same UNARY_STREAM interaction as above
    # while showing more advanced stream control features.
    async with stub.PromptModel.open() as stream:
        await stream.send_message(PromptRequest(prompt=res), end=True)
        #replies = [reply async for reply in stream]
        replies = list()
        message = ""
        async for reply in stream:
            print(reply)
            message += reply.message
            replies.append(reply)
            value.value = message
        print(replies)

    channel.close()

def _stream_prompt(b):
    loop = asyncio.get_event_loop()
    result = loop.run_until_complete(stream_prompt())


async def stream_redis_index() -> None:
    channel = Channel(port = 50050)
    stub = Seq2SeqStub(channel)
    res = prompt.value
    async with stub.PromptModel.open() as stream:
        await stream.send_message(PromptRequest(prompt=res), end=True)
        #replies = [reply async for reply in stream]
        replies = list()
        message = ""
        async for reply in stream:
            #print(reply)
            message += reply.message
            replies.append(reply)
            #value.value = message
        #print(replies)

    channel.close()

def _stream_redis_index(b):
    loop = asyncio.get_event_loop()
    result = loop.run_until_complete(stream_prompt())


header_button = create_expanded_html('My Chat Bot', 'success')
footer_button = create_expanded_html('Footer', 'success')

zips_dropdown  = widgets.Dropdown(
    options=['text-gen', 'chat'],
    value='text-gen',
    description='Example',
    disabled=False,
    )
prompt = widgets.Text(
    value=None,
    description='Prompt',
    disabled=False,
)
button = widgets.Button(
    description='Prompt',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Run report',
    icon='check' # (FontAwesome names without the `fa-` prefix)
)
button.on_click(_stream_prompt, False)
promp_template = widgets.HTML(
    description="Template",
    value="What is a good name for a company that makes {product}? List 5",
)
db_input = widgets.HTML(
    value="Input",
)
value = widgets.HTML(
    value="Ask question",
)
value.add_class('pre-wrap')


name = widgets.Text(description='Name:', padding=4)
color = widgets.Dropdown(description='Color:', padding=4, options=['red', 'orange', 'yellow', 'green', 'blue', 'indigo', 'violet'])
page1 = widgets.VBox(children=[zips_dropdown, promp_template, prompt, button, value], padding=4)

page2 = widgets.Box(children=[], padding=4)

tabs = widgets.Tab(children=[page1, page2])

tabs.set_title(0, 'Prompt')
tabs.set_title(1, 'Database')

AppLayout(header=header_button,
          left_sidebar=None,
          center=tabs,
          right_sidebar=None,
          footer=footer_button)
# Out:
# AppLayout(children=(HTML(value='', description='My Chat Bot', layout=Layout(grid_area='header', height='auto',…
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[3], line 39, in _stream_prompt(b)
#      37 def _stream_prompt(b):
#      38     loop = asyncio.get_event_loop()
# ---> 39     result = loop.run_until_complete(stream_prompt())
#
# File ~/.local/lib/python3.10/site-packages/nest_asyncio.py:90, in _patch_loop.<locals>.run_until_complete(self, future)
#      87 if not f.done():
#      88     raise RuntimeError(
#      89         'Event loop stopped before Future completed.')
# ---> 90 return f.result()
#
# File /usr/lib/python3.10/asyncio/futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception.with_traceback(self._exception_tb)
#     202 return self._result
#
# File /usr/lib/python3.10/asyncio/tasks.py:234, in Task.__step(***failed resolving arguments***)
#     232         result = coro.send(None)
#     233     else:
# --> 234         result = coro.throw(exc)
#     235 except StopIteration as exc:
#     236     if self._must_cancel:
#     237         # Task is cancelled right before coro stops.
#
# Cell In[3], line 24, in stream_prompt()
#      21 # This block performs the same UNARY_STREAM interaction as above
#      22 # while showing more advanced stream control features.
#      23 async with stub.PromptModel.open() as stream:
# ---> 24     await stream.send_message(PromptRequest(prompt=res), end=True)
#      25     #replies = [reply async for reply in stream]
#      26     replies = list()
#
# File ~/.local/lib/python3.10/site-packages/grpclib/client.py:241, in Stream.send_message(self, message, end)
#     221 """Coroutine to send message to the server.
#     222
#     223 If client sends UNARY request, then you should call this coroutine only
#    (...)
#     238 additional HTTP/2 frame.
#     239 """
#     240 if not self._send_request_done:
# --> 241     await self.send_request()
#     243 end_stream = end
#     244 if not self._cardinality.client_streaming:
#
# File ~/.local/lib/python3.10/site-packages/grpclib/client.py:173, in Stream.send_request(self, end)
#     169     raise ProtocolError('Unary request requires a message to be sent '
#     170                         'before ending outgoing stream')
#     172 with self._wrapper:
# --> 173     protocol = await self._channel.__connect__()
#     174     stream = protocol.processor.connection\
#     175         .create_stream(wrapper=self._wrapper)
#     177     headers = [
#     178         (':method', 'POST'),
#     179         (':scheme', self._channel._scheme),
#     180         (':path', self._method_name),
#     181         (':authority', self._channel._authority),
#     182     ]
#
# File ~/.local/lib/python3.10/site-packages/grpclib/client.py:728, in Channel.__connect__(self)
#     726 if not self._connected:
#     727     try:
# --> 728         self._protocol = await self._create_connection()
#     729     except Exception:
#     730         self._state = _ChannelState.TRANSIENT_FAILURE
#
# File ~/.local/lib/python3.10/site-packages/grpclib/client.py:711, in Channel._create_connection(self)
#     707     _, protocol = await self._loop.create_unix_connection(
#     708         self._protocol_factory, self._path, ssl=self._ssl,
#     709     )
#     710 else:
# --> 711     _, protocol = await self._loop.create_connection(
#     712         self._protocol_factory, self._host, self._port,
#     713         ssl=self._ssl,
#     714     )
#     715 return protocol
#
# File /usr/lib/python3.10/asyncio/base_events.py:1064, in BaseEventLoop.create_connection(self, protocol_factory, host, port, ssl, family, proto, flags, sock, local_addr, server_hostname, ssl_handshake_timeout, happy_eyeballs_delay, interleave)
#    1062 exceptions = [exc for sub in exceptions for exc in sub]
#    1063 if len(exceptions) == 1:
# -> 1064     raise exceptions[0]
#    1065 else:
#    1066     # If they all have the same str(), raise one.
#    1067     model = str(exceptions[0])
#
# File /usr/lib/python3.10/asyncio/base_events.py:1049, in BaseEventLoop.create_connection(self, protocol_factory, host, port, ssl, family, proto, flags, sock, local_addr, server_hostname, ssl_handshake_timeout, happy_eyeballs_delay, interleave)
#    1047 for addrinfo in infos:
#    1048     try:
# -> 1049         sock = await self._connect_sock(
#    1050             exceptions, addrinfo, laddr_infos)
#    1051         break
#    1052     except OSError:
#
# File /usr/lib/python3.10/asyncio/base_events.py:960, in BaseEventLoop._connect_sock(self, exceptions, addr_info, local_addr_infos)
#     958         else:  # all bind attempts failed
#     959             raise my_exceptions.pop()
# --> 960     await self.sock_connect(sock, address)
#     961     return sock
#     962 except OSError as exc:
#
# File /usr/lib/python3.10/asyncio/selector_events.py:500, in BaseSelectorEventLoop.sock_connect(self, sock, address)
#     498 fut = self.create_future()
#     499 self._sock_connect(fut, sock, address)
# --> 500 return await fut
#
# File /usr/lib/python3.10/asyncio/futures.py:285, in Future.__await__(self)
#     283 if not self.done():
#     284     self._asyncio_future_blocking = True
# --> 285     yield self  # This tells Task to wait for completion.
#     286 if not self.done():
#     287     raise RuntimeError("await wasn't used with future")
#
# File /usr/lib/python3.10/asyncio/tasks.py:304, in Task.__wakeup(self, future)
#     302 def __wakeup(self, future):
#     303     try:
# --> 304         future.result()
#     305     except BaseException as exc:
#     306         # This may also be a cancellation.
#     307         self.__step(exc)
#
# File /usr/lib/python3.10/asyncio/futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception.with_traceback(self._exception_tb)
#     202 return self._result
#
# File /usr/lib/python3.10/asyncio/selector_events.py:535, in BaseSelectorEventLoop._sock_connect_cb(self, fut, sock, address)
#     532     err = sock.getsockopt(socket.SOL_SOCKET, socket.SO_ERROR)
#     533     if err != 0:
#     534         # Jump to any except clause below.
# --> 535         raise OSError(err, f'Connect call failed {address}')
#     536 except (BlockingIOError, InterruptedError):
#     537     # socket is still registered, the callback will be retried later
#     538     pass
#
# ConnectionRefusedError: [Errno 111] Connect call failed ('127.0.0.1', 50050)
# message: "Starting teste \n with the template: \n What is a good name for a company that makes ? List 5\""
#
# message: "\n"
#
# message: "\n"
#
# message: "1"
#
# message: ")"
#
# message: " Tests"
#
# message: " R"
#
# message: " Us"
#
# message: " "
#
# message: "\n"
#
# message: "2"
#
# message: ")"
#
# message: " Exam"
#
# message: "pl"
#
# message: "ar"
#
# message: " "
#
# message: "\n"
#
# message: "3"
#
# message: ")"
#
# message: " Test"
#
# message: "ify"
#
# message: " "
#
# message: "\n"
#
# message: "4"
#
# message: ")"
#
# message: " Prof"
#
# message: "iciency"
#
# message: " Labs"
#
# message: "\n"
#
# message: "5"
#
# message: ")"
#
# message: " Test"
#
# message: "Drive"
#
#
# [message: "Starting teste \n with the template: \n What is a good name for a company that makes ? List 5\""
# , message: "\n"
# , message: "\n"
# , message: "1"
# , message: ")"
# , message: " Tests"
# , message: " R"
# , message: " Us"
# , message: " "
# , message: "\n"
# , message: "2"
# , message: ")"
# , message: " Exam"
# , message: "pl"
# , message: "ar"
# , message: " "
# , message: "\n"
# , message: "3"
# , message: ")"
# , message: " Test"
# , message: "ify"
# , message: " "
# , message: "\n"
# , message: "4"
# , message: ")"
# , message: " Prof"
# , message: "iciency"
# , message: " Labs"
# , message: "\n"
# , message: "5"
# , message: ")"
# , message: " Test"
# , message: "Drive"
# , ]
